# %% [markdown]
# # Import Library

# %%
import pandas as pd

# %% [markdown]
# # Data collection

# %%
data= pd.read_csv("C:\\Users\\Tharu\\OneDrive\\Documents\\ADDITION.csv")
df=pd.DataFrame(data)
df.head()
# Out:
#       x     y   sum
# 0   1.0   1.0   2.0
# 1   4.0   4.0   8.0
# 2   6.0   6.0  12.0
# 3  10.0  10.0  20.0
# 4  30.0  30.0  60.0

# %% [markdown]
# # Data Preprocessing

# %%
df.shape
# Out:
# (22, 3)

# %%
df.isna().sum()
# Out:
# x      0
# y      0
# sum    0
# dtype: int64

# %%
df.describe()
# Out:
#                  x            y          sum
# count    22.000000    22.000000    22.000000
# mean    136.786364   248.686364   385.472727
# std     229.622745   732.554988   938.706461
# min       1.000000     1.000000     2.000000
# 25%      15.500000    31.000000    66.500000
# 50%      40.150000    56.800000   117.450000
# 75%     175.000000    85.925000   245.975000
# max    1000.000000  3456.000000  4456.000000

# %%
df.corr()
# Out:
#             x         y       sum
# x    1.000000  0.867381  0.921509
# y    0.867381  1.000000  0.992563
# sum  0.921509  0.992563  1.000000

# %% [markdown]
# # Data Split

# %%
x=df[["x","y"]].values

# %%
y=df["sum"].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((17, 2), (5, 2), (17,), (5,))

# %% [markdown]
# x_train

# %% [markdown]
# # Model Selection and model training

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Model Testing

# %%
y_pred=model.predict(x_test)

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

print("mae:",mae)
print("mse:",mse)
print("r2:",r2)
# Out:
# mae: 1.6440182548649318e-13
# mse: 2.844510150786659e-26
# r2: 1.0

# %% [markdown]
# # Deployment

# %%
import joblib
joblib.dump(model, 'linear_model.pkl')
# Out:
# ['linear_model.pkl']
